# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.iloc[0:11, 5]
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7      True
# 8     False
# 9      True
# 10    False
# Name: job_work_from_home, dtype: bool

# %%
df.loc[:, 'salary_rate':'salary_hour_avg'].dropna(subset='salary_rate')
# Out:
#        salary_rate  salary_year_avg  salary_hour_avg
# 28            year         109500.0              NaN
# 43            hour              NaN             97.5
# 51            hour              NaN             72.5
# 77            year         140000.0              NaN
# 92            year         120000.0              NaN
# ...            ...              ...              ...
# 785624        year         139216.0              NaN
# 785641        year         150000.0              NaN
# 785648        year         221875.0              NaN
# 785682        year         157500.0              NaN
# 785692        year         157500.0              NaN
#
# [33067 rows x 3 columns]

# %%
## Select and display the job_title and job_location columns for the first 5 rows of the DF

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.iloc[0:5,1:3]
# Out:
#                                            job_title  \
# 0                                         Data Ninja
# 1                                       Data Analyst
# 2  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                             Data Engineer- Sr Jobs
#
#                    job_location
# 0                 Watertown, CT
# 1  Guadalajara, Jalisco, Mexico
# 2               Berlin, Germany
# 3               San Antonio, TX
# 4                Washington, DC

# %%
## Retrieve the columns starting with job_title all the way to job_posted_date for rows with an index of 5 to 9.

# %%
df.loc[5:9,'job_title':'job_posted_date']
# Out:
#                                   job_title         job_location  \
# 5                         GCP Data Engineer             Anywhere
# 6         Senior Data Engineer  - GCP Cloud         Dearborn, MI
# 7                             Data Engineer             Anywhere
# 8  Technology & Operations Business Analyst  Copenhagen, Denmark
# 9                         Data Scientist II             Anywhere
#
#             job_via         job_schedule_type  job_work_from_home  \
# 5  via ZipRecruiter  Contractor and Temp work                True
# 6      via LinkedIn                 Full-time               False
# 7      via LinkedIn                 Full-time                True
# 8   via Trabajo.org                 Full-time               False
# 9  via ZipRecruiter                 Full-time                True
#
#            search_location     job_posted_date
# 5                  Georgia 2023-11-07 14:01:59
# 6   Florida, United States 2023-03-27 13:18:18
# ...

# %%
## Retrieve the job_title and salary_year_avg for the first 15 rows where the job_country is 'United States'

# %%
df_us = df[df['job_country']=='United States']
df_us[['job_title','salary_year_avg']].iloc[:15]
# Out:
#                                             job_title  salary_year_avg
# 0                                          Data Ninja              NaN
# 3   LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...              NaN
# 5                                   GCP Data Engineer              NaN
# 6                   Senior Data Engineer  - GCP Cloud              NaN
# 9                                   Data Scientist II              NaN
# 11                                      Data Engineer              NaN
# 13                               Senior Data Engineer              NaN
# 17                             Data Science Team Lead              NaN
# 26                                      Data Engineer              NaN
# 27  Principal Data Engineer (Lead), Knowledge Grap...              NaN
# 30     Senior Data Engineer (Work from home Eligible)              NaN
# 32   Sr. Data Scientist (NLP) - Full-time / Part-time              NaN
# ...

# %%
## Select and display the job_title, job_location, and job_posted_date columns for rows where the job_posted_date is after '2023-05-01' using the loc method.

# %%
df_job_posted = df[df['job_posted_date'] > '2023-05-01']
df_job_posted.loc[:,['job_title','job_location','job_posted_date']]
# Out:
#                                                 job_title  \
# 0                                              Data Ninja
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# 5                                       GCP Data Engineer
# ...                                                   ...
# 785694                                      Data Engineer
# 785696                          Senior Analytics Engineer
# 785698      Data Engineer, Gerencia Business Intelligence
# 785701      Data Engineer, Gerencia Business Intelligence
# 785706                               Junior Data Engineer
#
#                      job_location     job_posted_date
# 0                   Watertown, CT 2023-06-16 13:44:15
# 2                 Berlin, Germany 2023-10-10 13:14:55
# 3                 San Antonio, TX 2023-07-04 13:01:41
# ...

# %%
df.loc[df['job_posted_date'] > '2023-05-01',['job_title','job_location','job_posted_date']]
# Out:
#                                                 job_title  \
# 0                                              Data Ninja
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# 5                                       GCP Data Engineer
# ...                                                   ...
# 785694                                      Data Engineer
# 785696                          Senior Analytics Engineer
# 785698      Data Engineer, Gerencia Business Intelligence
# 785701      Data Engineer, Gerencia Business Intelligence
# 785706                               Junior Data Engineer
#
#                      job_location     job_posted_date
# 0                   Watertown, CT 2023-06-16 13:44:15
# 2                 Berlin, Germany 2023-10-10 13:14:55
# 3                 San Antonio, TX 2023-07-04 13:01:41
# ...

# %%
df.iloc[10:15]
# Out:
#          job_title_short                                    job_title  \
# 10         Data Engineer         Erfahrene*r Data Engineer*in (m/w/d)
# 11         Data Engineer                                Data Engineer
# 12          Data Analyst  Stagiaire Data Analyst (H/F) - Lyon (69006)
# 13  Senior Data Engineer                         Senior Data Engineer
# 14         Data Engineer                                Data Engineer
#
#                                        job_location       job_via  \
# 10                               Basel, Switzerland  via LinkedIn
# 11               Colorado Springs, CO   (+3 others)  via The Muse
# 12                                     Lyon, France  via Jobijoba
# 13                                     New York, NY  via LinkedIn
# 14  Rio de Janeiro, State of Rio de Janeiro, Brazil     via BeBee
#
#            job_schedule_type  job_work_from_home       search_location  \
# 10                 Full-time               False           Switzerland
# ...

# %%
df.iloc[0:5,0:3]
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location
# 0                 Watertown, CT
# 1  Guadalajara, Jalisco, Mexico
# 2               Berlin, Germany
# 3               San Antonio, TX
# 4                Washington, DC

# %%
df.iloc[100,2]
# Out:
# 'Mountain View, CA'

# %%
df.iloc[-3:]
# Out:
#           job_title_short                                          job_title  \
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location              job_via  \
# 785738                             Malaysia     melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat  melalui Recruit.net
# 785740                                India       melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# 785738   Pekerjaan tetap               False        Malaysia
# 785739   Pekerjaan tetap               False           Sudan
# 785740   Pekerjaan tetap               False           India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# ...

# %%
df.iloc[[0,100,1000],[0,1]]
# Out:
#            job_title_short                                          job_title
# 0     Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 100         Data Scientist            Data Scientist, Risk Data Mining - USDS
# 1000         Data Engineer                            Data Engineer - Finance

# %%
subtabla = df.iloc[0:10,1:4]
subtabla
# Out:
#                                            job_title  \
# 0  Senior Clinical Data Engineer / Principal Clin...
# 1                                       Data Analyst
# 2  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                             Data Engineer- Sr Jobs
# 5                                  GCP Data Engineer
# 6                  Senior Data Engineer  - GCP Cloud
# 7                                      Data Engineer
# 8           Technology & Operations Business Analyst
# 9                                  Data Scientist II
#
#                    job_location             job_via
# 0                 Watertown, CT     via Work Nearby
# 1  Guadalajara, Jalisco, Mexico    via BeBee México
# 2               Berlin, Germany        via LinkedIn
# 3               San Antonio, TX   via Diversity.com
# 4                Washington, DC  via Clearance Jobs
# 5                      Anywhere    via ZipRecruiter
# ...

# %%
df.loc[5]
# Out:
# job_title_short                                              Data Engineer
# job_title                                                GCP Data Engineer
# job_location                                                      Anywhere
# job_via                                                   via ZipRecruiter
# job_schedule_type                                 Contractor and Temp work
# job_work_from_home                                                    True
# search_location                                                    Georgia
# job_posted_date                                        2023-11-07 14:01:59
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                  United States
# salary_rate                                                           None
# ...

# %%
df.loc[:9,['job_title','salary_year_avg']]
# Out:
#                                            job_title  salary_year_avg
# 0  Senior Clinical Data Engineer / Principal Clin...              NaN
# 1                                       Data Analyst              NaN
# 2  Data Engineer/Scientist/Analyst, Mid or Senior...              NaN
# 3  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...              NaN
# 4                             Data Engineer- Sr Jobs              NaN
# 5                                  GCP Data Engineer              NaN
# 6                  Senior Data Engineer  - GCP Cloud              NaN
# 7                                      Data Engineer              NaN
# 8           Technology & Operations Business Analyst              NaN
# 9                                  Data Scientist II              NaN

# %%
## Filtra todas las filas donde el título del trabajo (job_title) sea 'Data Scientist'

# %%
df.loc[df['job_title']=='Data scientist']
# Out:
#        job_title_short       job_title             job_location  \
# 681     Data Scientist  Data scientist            United States
# 1293    Data Scientist  Data scientist        Stockholm, Sweden
# 1297    Data Scientist  Data scientist                   France
# 2728    Data Scientist  Data scientist           Rabat, Morocco
# 2911    Data Scientist  Data scientist       Gothenburg, Sweden
# ...                ...             ...                      ...
# 779162  Data Scientist  Data scientist             Carlsbad, CA
# 780101  Data Scientist  Data scientist         Valbonne, France
# 780463  Data Scientist  Data scientist      Geneva, Switzerland
# 784830  Data Scientist  Data scientist  Middelburg, Netherlands
# 785460  Data Scientist  Data scientist        Brussels, Belgium
#
#                                job_via job_schedule_type  job_work_from_home  \
# 681                           via Jora         Full-time               False
# ...

# %%
## Muestra las columnas
## 'job_title', 'job_location' y 'salary_year_avg' solo para trabajos en 'United States'.

# %%
df.loc[df['job_location']=='United States',['job_title','job_location','salary_year_avg']]
# Out:
#                                                 job_title   job_location  \
# 26                                          Data Engineer  United States
# 156                                         Data Engineer  United States
# 339     Global Market Leading Energy Firm - Staff Data...  United States
# 372                                Data Scientist/Analyst  United States
# 572                                      Data Scientist I  United States
# ...                                                   ...            ...
# 785117                                 Sr. Data Scientist  United States
# 785156                                   Data Scientist 2  United States
# 785192                                     Data Scientist  United States
# 785346             Data Scientist with Security Clearance  United States
# 785557                         Data Scientist, All Levels  United States
#
#         salary_year_avg
# 26                  NaN
# 156                 NaN
# ...

# %%
## Selecciona todas las filas donde el salario promedio anual sea mayor a 150,000

# %%
df.loc[df['salary_year_avg']>150000]
# Out:
#               job_title_short  \
# 100            Data Scientist
# 212            Data Scientist
# 307             Data Engineer
# 339             Data Engineer
# 450            Data Scientist
# ...                       ...
# 785330  Senior Data Scientist
# 785340  Senior Data Scientist
# 785648         Data Scientist
# 785682         Data Scientist
# 785692         Data Scientist
#
#                                                 job_title  \
# 100               Data Scientist, Risk Data Mining - USDS
# 212          NATOIS-0008 Data Scientist (NS) - TUE 13 Jun
# 307                                         Data Engineer
# 339     Global Market Leading Energy Firm - Staff Data...
# 450                         Data Defense Developer - USDS
# ...                                                   ...
# 785330  Senior Data Scientist - TikTok US - Tech Services
# 785340          Senior Data Scientist - Product Analytics
# 785648  Director Data Scientist - Commercial Platforms...
# ...

# %%
## Selecciona todas las filas donde el salario esté entre 80,000 y 120,000

# %%
df.loc[(df['salary_year_avg']>=80000) & (df['salary_year_avg']<=120000)]
# Out:
#               job_title_short                                job_title  \
# 28             Data Scientist                      CRM Data Specialist
# 92              Data Engineer  Remote - Data Engineer - Permanent - W2
# 109              Data Analyst    Senior Supply Chain Analytics Analyst
# 116            Data Scientist                           Data Scientist
# 180              Data Analyst                         Data Analyst III
# ...                       ...                                      ...
# 784882           Data Analyst     Merchandising Analyst (Data Analyst)
# 785132  Senior Data Scientist  Senior Database Designer / Data Modeler
# 785187           Data Analyst                             Data Analyst
# 785488         Data Scientist                           Data Scientist
# 785515           Data Analyst                             Data Analyst
#
#                                    job_location                job_via  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
## Selecciona el salario promedio de todos los 'Data Analyst' ubicados en 'India'

# %%
df.loc[(df['job_country']=='India')&(df['job_title_short']=='Data Analyst'),'salary_year_avg']
# Out:
# 38       NaN
# 123      NaN
# 159      NaN
# 171      NaN
# 194      NaN
#           ..
# 785517   NaN
# 785548   NaN
# 785628   NaN
# 785691   NaN
# 785715   NaN
# Name: salary_year_avg, Length: 6121, dtype: float64

# %%
## Cambia el 'job_title' en la primera fila por 'Data Ninja'

# %%
df.loc[0,'job_title'] = 'Data Ninja'

# %%
## Selecciona 'job_title', 'company_location', 'salary_year_avg' para las filas 100 a 110

# %%
df.loc[100:110,['job_title', 'job_location', 'salary_year_avg']]
# Out:
#                                    job_title  \
# 100  Data Scientist, Risk Data Mining - USDS
# 101                             Data Analyst
# 102                           Data Scientist
# 103               Data Engineering Team Lead
# 104      Senior Software Engineer - Metadata
# 105                           Data Scientist
# 106               Senior Data Analyst (1541)
# 107                        Data Engineer H/F
# 108       Chapter Lead Data Engineers Poland
# 109    Senior Supply Chain Analytics Analyst
# 110                            Data Engineer
#
#                                        job_location  salary_year_avg
# 100                               Mountain View, CA         228222.0
# 101                                       Singapore              NaN
# 102  Rome, Metropolitan City of Rome Capital, Italy              NaN
# 103                                        Anywhere              NaN
# 104                                 Berlin, Germany              NaN
# ...

# %%
## Usa .iloc para obtener una subtabla pequeña (por ejemplo filas 0–4, columnas 0–3)
## y luego usa .loc sobre esa subtabla para filtrar solo los 'Data Engineer'.

# %%
subtabla = df.iloc[0:4,0:3]
subtabla.loc[df['job_title_short']=='Data Engineer']
# Out:
#   job_title_short                                          job_title  \
# 2   Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3   Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
#
#       job_location
# 2  Berlin, Germany
# 3  San Antonio, TX
