# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')
months = df['job_posted_month'].unique()
dict_months = {month: df[df['job_posted_month']==month] for month in months}
df_concat_cuarto = pd.concat([dict_months['Jan'], dict_months['Feb'], dict_months['Mar']], ignore_index=True)

# %% [markdown]
# Exportar a formato csv

# %%
df_concat_cuarto.to_csv('1er Cuarto.csv') # Tienes que agregar el .csv siempre

# %%
pd.read_csv('1er Cuarto.csv', index_col = 0) 
# Agregar siempre el 'index_col=0' para evitar dobre index
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
# ...

# %% [markdown]
# Exportar a Excel

# %%
df_concat_cuarto.to_excel('1er Cuarto.xlsx') 
# Tienes que agregar el .xlsx siempre
# El error debajo indica que debes instalar el modulo de excel, 'conda install openpyxl'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_concat_cuarto.to_excel('1er Cuarto.xlsx')
#       2 # Tienes que agregar el .xlsx siempre
#
# File c:\Users\JK_al\anaconda3\envs\Python_course\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
df_concat_cuarto.to_excel('1er Cuarto.xlsx')

# %% [markdown]
# Exportar a SQL

# %%
# Se tiene que importar libreria y crear un motor
from sqlalchemy import create_engine

#Aqui depende de la base de datos SQL que uses, en este caso MySQL
engine = create_engine('mysql+pymysql://usuario:contraseña@localhost/1er_Cuarto')

#metodo para exportar
df_concat_cuarto.to_sql('1er_Cuarto', con=engine, if_exists='replace', index=False)

#CHEQUEA CON CHATGPT!!!!!!!!
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Se tiene que importar libreria y crear un motor
# ----> 2 from sqlalchemy import create_engine
#       4 #Aqui depende de la base de datos SQL que uses, en este caso MySQL
#       5 engine = create_engine('mysql+pymysql://usuario:contraseña@localhost/1er_Cuarto')
#
# ModuleNotFoundError: No module named 'sqlalchemy'
